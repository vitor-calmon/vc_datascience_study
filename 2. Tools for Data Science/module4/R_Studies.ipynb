# %% [markdown]
# # Creating Data Visualizations using ggplot
#
# Objective of Exercise:
#
# This lab introduces you to plotting in R with ggplot and GGally. GGally is an extension of ggplot2.
#
# Pre Requisite:
#
# Before loading the GGAlly package, ensure its dependencies are installed. Run the following commands in the Console window, as shown in the screenshot below, and then continue with the steps in the Exercise.

# %% [markdown]
# 1. Read and view the first 5 rows of the Data using the following:

# %%
library(datasets)

#Load Data

data(mtcars)

#View first 5 rows

head(mtcars, 5)
# Out:
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2

# %% [markdown]
# Copy and paste the following code to load the ggplot package and create a scatterplot of disp and mpg.

# %%
# install.packages("ggplot2")
# Out:
# Installing package into 'C:/Users/7490/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
#
# also installing the dependencies 'farver', 'labeling', 'RColorBrewer', 'viridisLite', 'gtable', 'isoband', 'S7', 'scales'
# package 'farver' successfully unpacked and MD5 sums checked
# package 'labeling' successfully unpacked and MD5 sums checked
# package 'RColorBrewer' successfully unpacked and MD5 sums checked
# package 'viridisLite' successfully unpacked and MD5 sums checked
# package 'gtable' successfully unpacked and MD5 sums checked
# package 'isoband' successfully unpacked and MD5 sums checked
# package 'S7' successfully unpacked and MD5 sums checked
# package 'scales' successfully unpacked and MD5 sums checked
# package 'ggplot2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\7490\AppData\Local\Temp\RtmpaC0kSW\downloaded_packages

# %%
#load ggplot package
library(ggplot2)

#create a scatterplot of displacement (disp) and miles per gallon (mpg)

ggplot(aes(x=disp,y=mpg,),data=mtcars)+geom_point()
# Out:
# plot without title

# %% [markdown]
# Use the following code to add a title.

# %%
#Add a title

ggplot(aes(x=disp,y=mpg,),data=mtcars)+geom_point()+ggtitle("displacement vs miles per gallon")
# Out:
# plot without title

# %% [markdown]
# Use the following code to change the name of the x-axis and y-axis

# %%
#change axis name

ggplot(aes(x=disp,y=mpg,),data=mtcars)+geom_point()+ggtitle("displacement vs miles per gallon") + labs(x = "Displacement", y = "Miles per Gallon")
# Out:
# plot without title

# %% [markdown]
# Use the following to create a boxplot of the the distribution of mpg for the individual Engine types vs Engine (0 = V-shaped, 1 = straight) To do this you have to make vs a string or factor.

# %%
#make vs a factor
mtcars$vs <- as.factor(mtcars$vs)

#create boxplot of the distribution for v-shaped and straight Engine

ggplot(aes(x=vs, y=mpg), data = mtcars) + geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# Add color to the boxplots to help differentiate:

# %%
ggplot(aes(x=vs, y=mpg, fill = vs), data = mtcars) + 
  geom_boxplot(alpha=0.3) +
  theme(legend.position="none")
# Out:
# plot without title

# %% [markdown]
# Finally, let us create the histogram of weight wt.

# %%
ggplot(aes(x=wt),data=mtcars) + geom_histogram(binwidth=0.5)
# Out:
# plot without title

# %% [markdown]
# # Plotting with RStudio
#
# Objective of Exercise:
#
# This lab introduces you to plotting in R with ggplot and GGally. GGally is an extension of ggplot2.
#
# Pre Requisite:
#
# Before loading the GGAlly package, ensure its dependencies are installed. Run the following commands in the Console window, as shown in the screenshot below, and then continue with the steps in the Exercise.

# %%
install.packages("https://cran.r-project.org/src/contrib/Archive/patchwork/patchwork_1.1.0.tar.gz", repos = NULL, type = "source", dependencies = TRUE)

install.packages("https://cran.r-project.org/src/contrib/Archive/broom.helpers/broom.helpers_1.4.0.tar.gz", repos = NULL, type = "source", dependencies = TRUE)

install.packages("https://cran.r-project.org/src/contrib/Archive/ggstats/ggstats_0.5.0.tar.gz", repos = NULL, type = "source", dependencies = TRUE)
# Out:
# Installing package into 'C:/Users/7490/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
#
# Installing package into 'C:/Users/7490/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
#
# Warning message in install.packages("https://cran.r-project.org/src/contrib/Archive/broom.helpers/broom.helpers_1.4.0.tar.gz", :
# "installation of package 'C:/Users/7490/AppData/Local/Temp/RtmpaC0kSW/downloaded_packages/broom.helpers_1.4.0.tar.gz' had non-zero exit status"
# Installing package into 'C:/Users/7490/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
#
# Warning message in install.packages("https://cran.r-project.org/src/contrib/Archive/ggstats/ggstats_0.5.0.tar.gz", :
# "installation of package 'C:/Users/7490/AppData/Local/Temp/RtmpaC0kSW/downloaded_packages/ggstats_0.5.0.tar.gz' had non-zero exit status"
